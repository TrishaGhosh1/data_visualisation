# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("/content/seeds.csv")
data
# Out:
#       AREA  PERIMETER  COMPACTNESS  LENGTH  WIDTH  ASSYMMETRY_COEFFICIENT  \
# 0    15.26      14.84       0.8710   5.763  3.312                   2.221
# 1    14.88      14.57       0.8811   5.554  3.333                   1.018
# 2    14.29      14.09       0.9050   5.291  3.337                   2.699
# 3    13.84      13.94       0.8955   5.324  3.379                   2.259
# 4    16.14      14.99       0.9034   5.658  3.562                   1.355
# ..     ...        ...          ...     ...    ...                     ...
# 135  15.38      14.66       0.8990   5.477  3.465                   3.600
# 136  17.36      15.76       0.8785   6.145  3.574                   3.526
# 137  15.57      15.15       0.8527   5.920  3.231                   2.640
# 138  15.60      15.11       0.8580   5.832  3.286                   2.725
# 139  16.23      15.18       0.8850   5.872  3.472                   3.769
#
#      GROOVE_LENGTH  TYPE
# 0            5.220     1
# 1            4.956     1
# ...

# %%
data.iloc[2:4,3:5]
# Out:
#    LENGTH  WIDTH
# 2   5.291  3.337
# 3   5.324  3.379

# %%
data.describe()
# Out:
#              AREA   PERIMETER  COMPACTNESS      LENGTH       WIDTH  \
# count  140.000000  140.000000   140.000000  140.000000  140.000000
# mean    16.334357   15.215000     0.881794    5.828043    3.461021
# std      2.406400    1.099006     0.015887    0.406740    0.282686
# min     11.230000   12.630000     0.839200    4.902000    2.850000
# 25%     14.362500   14.335000     0.871450    5.519000    3.239250
# 50%     16.130000   15.130000     0.881850    5.808500    3.463500
# 75%     18.720000   16.205000     0.894250    6.146750    3.693250
# max     21.180000   17.250000     0.918300    6.675000    4.033000
#
#        ASSYMMETRY_COEFFICIENT  GROOVE_LENGTH        TYPE
# count              140.000000     140.000000  140.000000
# mean                 3.156101       5.553907    1.500000
# std                  1.272003       0.534693    0.501795
# min                  0.765100       4.519000    1.000000
# 25%                  2.220000       5.095500    1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AREA                    140 non-null    float64
#  1   PERIMETER               140 non-null    float64
#  2   COMPACTNESS             140 non-null    float64
#  3   LENGTH                  140 non-null    float64
#  4   WIDTH                   140 non-null    float64
#  5   ASSYMMETRY_COEFFICIENT  140 non-null    float64
#  6   GROOVE_LENGTH           140 non-null    float64
#  7   TYPE                    140 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 8.9 KB

# %%
data.shape
# Out:
# (140, 8)

# %%
data.head()
# Out:
#     AREA  PERIMETER  COMPACTNESS  LENGTH  WIDTH  ASSYMMETRY_COEFFICIENT  \
# 0  15.26      14.84       0.8710   5.763  3.312                   2.221
# 1  14.88      14.57       0.8811   5.554  3.333                   1.018
# 2  14.29      14.09       0.9050   5.291  3.337                   2.699
# 3  13.84      13.94       0.8955   5.324  3.379                   2.259
# 4  16.14      14.99       0.9034   5.658  3.562                   1.355
#
#    GROOVE_LENGTH  TYPE
# 0          5.220     1
# 1          4.956     1
# 2          4.825     1
# 3          4.805     1
# 4          5.175     1

# %%
data.tail()
# Out:
#       AREA  PERIMETER  COMPACTNESS  LENGTH  WIDTH  ASSYMMETRY_COEFFICIENT  \
# 135  15.38      14.66       0.8990   5.477  3.465                   3.600
# 136  17.36      15.76       0.8785   6.145  3.574                   3.526
# 137  15.57      15.15       0.8527   5.920  3.231                   2.640
# 138  15.60      15.11       0.8580   5.832  3.286                   2.725
# 139  16.23      15.18       0.8850   5.872  3.472                   3.769
#
#      GROOVE_LENGTH  TYPE
# 135          5.439     2
# 136          5.971     2
# 137          5.879     2
# 138          5.752     2
# 139          5.922     2

# %%
data[6:10]
# Out:
#     AREA  PERIMETER  COMPACTNESS  LENGTH  WIDTH  ASSYMMETRY_COEFFICIENT  \
# 6  14.69      14.49       0.8799   5.563  3.259                   3.586
# 7  14.11      14.10       0.8911   5.420  3.302                   2.700
# 8  16.63      15.46       0.8747   6.053  3.465                   2.040
# 9  16.44      15.25       0.8880   5.884  3.505                   1.969
#
#    GROOVE_LENGTH  TYPE
# 6          5.219     1
# 7          5.000     1
# 8          5.877     1
# 9          5.533     1

# %%
data.columns
# Out:
# Index(['AREA', 'PERIMETER', 'COMPACTNESS', 'LENGTH', 'WIDTH',
#        'ASSYMMETRY_COEFFICIENT', 'GROOVE_LENGTH', 'TYPE'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['AREA', 'PERIMETER', 'COMPACTNESS', 'LENGTH', 'WIDTH',
#        'ASSYMMETRY_COEFFICIENT', 'GROOVE_LENGTH', 'TYPE'], dtype=object)

# %%
data.sort_index(axis=1,ascending=True)
# Out:
#       AREA  ASSYMMETRY_COEFFICIENT  COMPACTNESS  GROOVE_LENGTH  LENGTH  \
# 0    15.26                   2.221       0.8710          5.220   5.763
# 1    14.88                   1.018       0.8811          4.956   5.554
# 2    14.29                   2.699       0.9050          4.825   5.291
# 3    13.84                   2.259       0.8955          4.805   5.324
# 4    16.14                   1.355       0.9034          5.175   5.658
# ..     ...                     ...          ...            ...     ...
# 135  15.38                   3.600       0.8990          5.439   5.477
# 136  17.36                   3.526       0.8785          5.971   6.145
# 137  15.57                   2.640       0.8527          5.879   5.920
# 138  15.60                   2.725       0.8580          5.752   5.832
# 139  16.23                   3.769       0.8850          5.922   5.872
#
#      PERIMETER  TYPE  WIDTH
# 0        14.84     1  3.312
# 1        14.57     1  3.333
# ...

# %%
data["AREA"].head()
# Out:
# 0    15.26
# 1    14.88
# 2    14.29
# 3    13.84
# 4    16.14
# Name: AREA, dtype: float64

# %%
print(data["LENGTH"].mean())
print(data["LENGTH"].median())
print(data["LENGTH"].mode()[0])
print(data["LENGTH"].min())
print(data["LENGTH"].max())
# Out:
# 5.828042857142857
# 5.8085
# 5.395
# 4.902
# 6.675

# %%
data.groupby(["LENGTH","WIDTH"]).sum()
# Out:
#                AREA  PERIMETER  COMPACTNESS  ASSYMMETRY_COEFFICIENT  \
# LENGTH WIDTH
# 4.902  2.879  11.23      12.63       0.8840                   2.269
# 5.008  2.850  11.42      12.86       0.8683                   2.700
# 5.076  3.042  12.36      13.19       0.8923                   3.220
# 5.099  2.936  12.08      13.23       0.8664                   1.415
# 5.119  3.383  13.99      13.83       0.9183                   5.234
# ...             ...        ...          ...                     ...
# 6.573  4.033  21.18      17.21       0.8989                   5.780
# 6.579  3.814  20.71      17.23       0.8763                   4.451
# 6.581  3.785  20.10      16.99       0.8746                   1.955
# 6.666  3.485  18.36      16.52       0.8452                   4.933
# 6.675  3.763  19.94      16.92       0.8752                   3.252
#
#               GROOVE_LENGTH  TYPE
# LENGTH WIDTH
# 4.902  2.879          4.703     1
# 5.008  2.850          4.607     1
# ...

# %%
data.isnull()
# Out:
#       AREA  PERIMETER  COMPACTNESS  LENGTH  WIDTH  ASSYMMETRY_COEFFICIENT  \
# 0    False      False        False   False  False                   False
# 1    False      False        False   False  False                   False
# 2    False      False        False   False  False                   False
# 3    False      False        False   False  False                   False
# 4    False      False        False   False  False                   False
# ..     ...        ...          ...     ...    ...                     ...
# 135  False      False        False   False  False                   False
# 136  False      False        False   False  False                   False
# 137  False      False        False   False  False                   False
# 138  False      False        False   False  False                   False
# 139  False      False        False   False  False                   False
#
#      GROOVE_LENGTH   TYPE
# 0            False  False
# ...

# %%
data.isnull().sum()
# Out:
# AREA                      0
# PERIMETER                 0
# COMPACTNESS               0
# LENGTH                    0
# WIDTH                     0
# ASSYMMETRY_COEFFICIENT    0
# GROOVE_LENGTH             0
# TYPE                      0
# dtype: int64

# %%
data["LENGTH"].corr(data["AREA"])
# Out:
# 0.9394946527379635

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(18,5))
sns.barplot(x="LENGTH",y="AREA",data=data)
# Out:
# <Axes: xlabel='LENGTH', ylabel='AREA'>

# %%
corr = data[["AREA","PERIMETER"]].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.histplot(x="LENGTH",data=data)
# Out:
# <Axes: xlabel='LENGTH', ylabel='Count'>

# %%
sns.displot(data["AREA"], kde=True)

# %%
sns.scatterplot(x="LENGTH",y="WIDTH",data=data)
# Out:
# <Axes: xlabel='LENGTH', ylabel='WIDTH'>

# %%
sns.boxplot(data=data,x='AREA')
# Out:
# <Axes: xlabel='AREA'>
