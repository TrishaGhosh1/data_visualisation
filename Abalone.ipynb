# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("/content/Abalone_data.csv")
data
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M      70        53      18          45.1            19.9
# 1      F     106        84      27         135.4            51.3
# 2      M      88        73      25         103.2            43.1
# 3      I      66        51      16          41.0            17.9
# 4      I      85        60      19          70.3            28.2
# ...   ..     ...       ...     ...           ...             ...
# 4171   F     113        90      33         177.4            74.0
# 4172   M     118        88      27         193.2            87.8
# 4173   M     120        95      41         235.2           105.1
# 4174   F     125        97      30         218.9           106.2
# 4175   M     142       111      39         389.7           189.1
#
#       Viscera_weight  Shell_weight  Rings
# 0                9.7          14.0      7
# 1               28.3          42.0      9
# 2               22.8          31.0     10
# ...

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4176.000000  4176.000000  4176.000000   4176.000000     4176.000000
# mean    104.801724    81.578305    27.905412    165.763506       71.879957
# std      24.020509    19.849906     8.365278     98.084710       44.395943
# min      15.000000    11.000000     0.000000      0.400000        0.200000
# 25%      90.000000    70.000000    23.000000     88.300000       37.200000
# 50%     109.000000    85.000000    28.000000    159.950000       67.200000
# 75%     123.000000    96.000000    33.000000    230.650000      100.400000
# max     163.000000   130.000000   226.000000    565.100000      297.600000
#
#        Viscera_weight  Shell_weight        Rings
# count     4176.000000   4176.000000  4176.000000
# mean        36.122534     47.770426     9.932471
# std         21.924091     27.842510     3.223601
# min          0.100000      0.300000     1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4176 entries, 0 to 4175
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4176 non-null   object
#  1   Length          4176 non-null   int64
#  2   Diameter        4176 non-null   int64
#  3   Height          4176 non-null   int64
#  4   Whole_weight    4176 non-null   float64
#  5   Shucked_weight  4176 non-null   float64
#  6   Viscera_weight  4176 non-null   float64
#  7   Shell_weight    4176 non-null   float64
#  8   Rings           4176 non-null   int64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 293.8+ KB

# %%
data.shape
# Out:
# (4176, 9)

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M      70        53      18          45.1            19.9             9.7
# 1   F     106        84      27         135.4            51.3            28.3
# 2   M      88        73      25         103.2            43.1            22.8
# 3   I      66        51      16          41.0            17.9             7.9
# 4   I      85        60      19          70.3            28.2            15.5
#
#    Shell_weight  Rings
# 0          14.0      7
# 1          42.0      9
# 2          31.0     10
# 3          11.0      7
# 4          24.0      8

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 4171   F     113        90      33         177.4            74.0
# 4172   M     118        88      27         193.2            87.8
# 4173   M     120        95      41         235.2           105.1
# 4174   F     125        97      30         218.9           106.2
# 4175   M     142       111      39         389.7           189.1
#
#       Viscera_weight  Shell_weight  Rings
# 4171            47.8          49.8     11
# 4172            42.9          52.1     10
# 4173            57.5          61.6      9
# 4174            52.2          59.2     10
# 4175            75.3          99.0     12

# %%
data[1:10]
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 1   F     106        84      27         135.4            51.3            28.3
# 2   M      88        73      25         103.2            43.1            22.8
# 3   I      66        51      16          41.0            17.9             7.9
# 4   I      85        60      19          70.3            28.2            15.5
# 5   F     106        83      30         155.5            47.4            28.3
# 6   F     109        85      25         153.6            58.8            29.9
# 7   M      95        74      25         101.9            43.3            22.5
# 8   F     110        88      30         178.9            62.9            30.2
# 9   F     105        76      28         121.3            38.8            29.5
#
#    Shell_weight  Rings
# 1          42.0      9
# 2          31.0     10
# 3          11.0      7
# 4          24.0      8
# 5          66.0     20
# 6          52.0     16
# ...

# %%
data.iloc[1:3,1:6]
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight
# 1     106        84      27         135.4            51.3
# 2      88        73      25         103.2            43.1

# %%
data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %%
data["Length"].head()
# Out:
# 0     70
# 1    106
# 2     88
# 3     66
# 4     85
# Name: Length, dtype: int64

# %%
print(data["Height"].mean())
print(data["Height"].median())
print(data["Height"].mode()[0])
print(data["Height"].min())
print(data["Height"].max())
# Out:
# 27.905411877394634
# 28.0
# 30
# 0
# 226

# %%
data.groupby(["Height","Length"]).sum()
# Out:
#               Sex  Diameter  Whole_weight  Shucked_weight  Viscera_weight  \
# Height Length
# 0      63       I        46          26.8            11.5             5.7
#        86       I        68          85.6            41.3            17.2
# 2      15       I        11           0.4             0.2             0.1
# 3      33       I        23           2.9             1.1             0.6
#        127      F        99         231.3           102.3            61.6
# ...            ..       ...           ...             ...             ...
# 50     119      F        94         256.6            92.4            49.5
#        155      M       126         555.9           269.7           152.0
#        163      F       130         451.0           178.1            84.0
# 103    141      M       113         442.0           221.5            97.3
# 226    91       F        71         118.8            66.4            23.2
#
#                Shell_weight  Rings
# Height Length
# ...

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
data['Height'].corr(data['Diameter'])
# Out:
# 0.8337052814859393

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(19,5))
sns.boxplot(data=data,x='Length',y='Rings')
# Out:
# <Axes: xlabel='Length', ylabel='Rings'>

# %%
sns.boxplot(data=data,x='Length')
# Out:
# <Axes: xlabel='Length'>

# %%
corr = data[["Length","Height"]].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.histplot(x="Diameter",data=data)
# Out:
# <Axes: xlabel='Diameter', ylabel='Count'>

# %%
sns.displot(data["Whole_weight"], kde=True)

# %%
sns.scatterplot(x="Length",y="Height",data=data)
# Out:
# <Axes: xlabel='Length', ylabel='Height'>
