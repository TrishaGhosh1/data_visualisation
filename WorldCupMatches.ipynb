# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("WorldCupMatches.csv")
data
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
data.head() # head() displays the first 5 rows from the top of a dataframe if a number is not specified.
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
data.tail() # tail() displays the first 5 rows from the bottom of a dataframe if a number is not specified.
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4567   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4568   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4567              NaN            NaN            NaN         NaN
# 4568              NaN            NaN            NaN         NaN
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4567                   NaN                   NaN     NaN         NaN
# ...

# %%
print(data.shape) # .shape returns the number of rows and columns in dataframe in the form of tuple. 
print("The rows of the dataframe is:",data.shape[0])
print("The columns of the dataframe is:",data.shape[1])
# Out:
# (4572, 20)
# The rows of the dataframe is: 4572
# The columns of the dataframe is: 20

# %%
'''.columns is an attribute that provides access to the columns label of a dataframe.
 It returns an index object representing the name of the columns in dataframe. '''
print(data.columns)
print("\n\nName of the columns:") 
for i in data.columns:
  print(i)
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')
#
#
# Name of the columns:
# Year
# Datetime
# Stage
# Stadium
# City
# Home Team Name
# Home Team Goals
# Away Team Goals
# Away Team Name
# Win conditions
# Attendance
# Half-time Home Goals
# Half-time Away Goals
# Referee
# Assistant 1
# Assistant 2
# RoundID
# MatchID
# Home Team Initials
# Away Team Initials

# %%
data[4:14] # print the rows from index 4 to 13.
# Out:
#       Year              Datetime    Stage             Stadium         City  \
# 4   1930.0  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5   1930.0  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6   1930.0  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7   1930.0  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8   1930.0  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9   1930.0  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
# 10  1930.0  19 Jul 1930 - 15:00   Group 1  Estadio Centenario  Montevideo
# 11  1930.0  20 Jul 1930 - 13:00   Group 2  Estadio Centenario  Montevideo
# 12  1930.0  20 Jul 1930 - 15:00   Group 4  Estadio Centenario  Montevideo
# 13  1930.0  21 Jul 1930 - 14:50   Group 3  Estadio Centenario  Montevideo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 4       Argentina              1.0              0.0         France
# ...

# %%
data["Year"] # print "Year" column from dataframe
# Out:
# 0       1930.0
# 1       1930.0
# 2       1930.0
# 3       1930.0
# 4       1930.0
#          ...
# 4567       NaN
# 4568       NaN
# 4569       NaN
# 4570       NaN
# 4571       NaN
# Name: Year, Length: 4572, dtype: float64

# %%
data['City'].value_counts() # value_counts() returns a series that contain counts of unique values.
# Out:
# City
# Mexico City        23
# Montevideo         18
# Rio De Janeiro     18
# Guadalajara        17
# Johannesburg       15
#                    ..
# Eskilstuna          1
# Orebro              1
# Reims               1
# Antibes             1
# Lille               1
# Name: count, Length: 151, dtype: int64

# %%
data.describe() # .describe() returns description of the data in the dataframe.
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
data.info() #.info() print the information about the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
data['Attendance'].max() # max() function returns the maximum value in the given column.
# Out:
# 173850.0

# %%
data['Attendance'].min() # min() function returns the minimum value in the given column.
# Out:
# 2000.0

# %%
data['Half-time Home Goals'].mean() # mean() function returns the mean value of a column in a dataframe.
# Out:
# 0.7089201877934272

# %%
data['Home Team Goals'].median() # median() function returns the median value of a column in a dataframe.
# Out:
# 2.0

# %%
data['Home Team Goals'].mode() # mode() function returns the mode value of a column in a dataframe.
# Out:
# 0    1.0
# Name: Home Team Goals, dtype: float64

# %%
data.corr(numeric_only=True) #find the correlation among the columns in the dataframe.
# Out:
#                           Year  Home Team Goals  Away Team Goals  Attendance  \
# Year                  1.000000        -0.381332         0.075339    0.314698
# Home Team Goals      -0.381332         1.000000         0.012474   -0.117751
# Away Team Goals       0.075339         0.012474         1.000000   -0.029801
# Attendance            0.314698        -0.117751        -0.029801    1.000000
# Half-time Home Goals -0.288909         0.729536        -0.006304   -0.126756
# Half-time Away Goals  0.020934        -0.009530         0.693780   -0.037136
# RoundID               0.343106        -0.110075        -0.005345    0.069394
# MatchID               0.636591        -0.196100         0.082687    0.164686
#
#                       Half-time Home Goals  Half-time Away Goals   RoundID  \
# Year                             -0.288909              0.020934  0.343106
# Home Team Goals                   0.729536             -0.009530 -0.110075
# ...

# %%
'''The isnull() returns a DataFrame object where all the values are replaced 
with a Boolean value True for NULL values, and otherwise False.'''
data.isnull()
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
# ...

# %%
data.isnull().sum() # display the series that contain sum of null values for all columns
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
d1=data.fillna(data.mean(numeric_only=True))
d1
# Out:
#              Year              Datetime    Stage         Stadium         City  \
# 0     1930.000000  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.000000  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.000000  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.000000  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.000000  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...           ...                   ...      ...             ...          ...
# 4567  1985.089202                   NaN      NaN             NaN          NaN
# 4568  1985.089202                   NaN      NaN             NaN          NaN
# 4569  1985.089202                   NaN      NaN             NaN          NaN
# 4570  1985.089202                   NaN      NaN             NaN          NaN
# 4571  1985.089202                   NaN      NaN             NaN          NaN
#
# ...

# %%
d1.isnull().sum()
# Out:
# Year                       0
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals            0
# Away Team Goals            0
# Away Team Name          3720
# Win conditions          3720
# Attendance                 0
# Half-time Home Goals       0
# Half-time Away Goals       0
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                    0
# MatchID                    0
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Home Team Goals',y='Attendance',data=d1)
plt.show()

# %%
sns.pairplot(d1,hue='Attendance')
plt.show()

# %%
plt.figure(figsize=(15,4))
sns.boxplot(x='Home Team Goals',y='Away Team Goals', data=d1, color="green")
plt.show()

# %%
sns.scatterplot(x="Home Team Goals",y="Attendance",data=d1)
plt.show()

# %%
corr=d1[['Attendance','Year']].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.histplot(x="Attendance",data=d1)
plt.show()

# %%
sns.displot(x="Half-time Home Goals",data=d1)
plt.show()
